# %%
import pandas as pd

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[4,5,6],'c':[7,8,9]})
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df['a'],df.iloc[:,0]
# Out:
# (0    1
#  1    2
#  2    3
#  Name: a, dtype: int64, 0    1
#  1    2
#  2    3
#  Name: a, dtype: int64)

# %%
df.iloc[0]
# Out:
# a    1
# b    4
# c    7
# Name: 0, dtype: int64

# %%
df.loc[0]
# Out:
# a    1
# b    4
# c    7
# Name: 0, dtype: int64
